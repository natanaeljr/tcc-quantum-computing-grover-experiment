# %%
from qiskit.tools.visualization import plot_histogram, plot_distribution
from pprint import pprint

circuit_results = {   '001010001010100001010': 0.185546875,
                               '001100001100010001100': 0.181640625,
                               '010001010001100010001': 0.1630859375,
                               '010100010100001010100': 0.150390625,
                               '100001100001010100001': 0.1728515625,
                               '100010100010001100010': 0.146484375}


# results = [x for x in circuit_results.items() if x[1] > 0.001]
states = {}
for key, value in circuit_results.items():
    if value > 0.001:
        states[key] = value

pprint(states)

display(plot_distribution(states))
# Out:
# {'001010001010100001010': 0.185546875,
#  '001100001100010001100': 0.181640625,
#  '010001010001100010001': 0.1630859375,
#  '010100010100001010100': 0.150390625,
#  '100001100001010100001': 0.1728515625,
#  '100010100010001100010': 0.146484375}
