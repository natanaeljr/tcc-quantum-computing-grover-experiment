# %%
from qiskit.tools.visualization import plot_histogram, plot_distribution
from pprint import pprint

circuit_results = {   '001001010100': 0.0875,
                               '001001100010': 0.0805,
                               '001010100010': 0.08825,
                               '001100010100': 0.083,
                               '010001100001': 0.08025,
                               '010010001100': 0.086,
                               '010010100001': 0.07925,
                               '010100001100': 0.081,
                               '100001010001': 0.0835,
                               '100010001010': 0.08,
                               '100100001010': 0.08375,
                               '100100010001': 0.087}

sum = 0
# results = [x for x in circuit_results.items() if x[1] > 0.001]
states = {}
for key, value in circuit_results.items():
    if value > 0.001:
        states[key] = value
        sum += value


print("sum:", sum)
pprint(states)

display(plot_distribution(states))
# Out:
# sum: 0.9999999999999999
# {'001001010100': 0.0875,
#  '001001100010': 0.0805,
#  '001010100010': 0.08825,
#  '001100010100': 0.083,
#  '010001100001': 0.08025,
#  '010010001100': 0.086,
#  '010010100001': 0.07925,
#  '010100001100': 0.081,
#  '100001010001': 0.0835,
#  '100010001010': 0.08,
#  '100100001010': 0.08375,
#  '100100010001': 0.087}
